# %% [markdown]
# ## Data Reading

# %% [markdown]
# ### Reading csv files

# %%
df_sales = spark.read.format("csv") \
  .option("header", "true") \
    .option("inferSchema", "true") \
      .load("/Volumes/retail_catalog/bigmart_schema/bigmart_volume/BigMart Sales.csv")

# %%
df_sales.display()

# %%
df_sales.printSchema()

# %% [markdown]
# ### Reading Json files

# %%
df_movie_json = spark.read \
    .option("multiLine", "true") \
    .json("/Volumes/retail_catalog/bigmart_schema/bigmart_volume/large-file.json")

# %%
l1 = dbutils.fs.ls("/Volumes/retail_catalog/bigmart_schema/bigmart_volume")
for i in l1:
    print(i.name)

# %%
df_json = spark.read.format('json') \
    .option('header', True) \
        .option("inferSchema", True) \
            .option("multiline", False) \
                .load("/Volumes/retail_catalog/bigmart_schema/bigmart_volume/drivers.json")

# %% [markdown]
# ### Explore data

# %%
df_sales.display()

# %% [markdown]
# ### Schema definition

# %%
df_sales.printSchema()

# %% [markdown]
# ## DDL Schema

# %%
my_ddl_schema = """
                Item_Identifier STRING,
                Item_Weight STRING,
                Item_Fat_Content STRING,
                Item_Visibility DOUBLE,
                Item_Type STRING,
                Item_MRP DOUBLE,
                Outlet_Identifier STRING,
                Outlet_Establishment_Year INT,
                Outlet_Size STRING,
                Outlet_Location_Type STRING,
                Outlet_Type STRING,
                Item_Outlet_Sales DOUBLE
"""

# %%
df = spark.read.format("csv") \
    .schema(my_ddl_schema) \
        .option("header", True) \
            .load("/Volumes/retail_catalog/bigmart_schema/bigmart_volume/BigMart Sales.csv")
df.display()
df.printSchema()

# %% [markdown]
# ## StructType and StructFiled

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
my_struct_schema = StructType([
                                StructField("Item_Identifier", StringType(), True),
                                StructField("Item_Weight", StringType(), True),
                                StructField("Item_Fat_Content", StringType(), True),
                                StructField("Item_Visibility", DoubleType(), True),
                                StructField("Item_Type", StringType(), True),
                                StructField("Item_MRP", DoubleType(), True),
                                StructField("Outlet_Identifier", StringType(), True),
                                StructField("Outlet_Establishment_Year", IntegerType(), True),
                                StructField("Outlet_Size", StringType(), True),
                                StructField("Outlet_Location_Type", StringType(), True),
                                StructField("Outlet_Type", StringType(), True),
                                StructField("Item_Outlet_Sales", DoubleType(), True)
])

# %%
df = spark.read.format("csv") \
    .schema(my_struct_schema) \
        .option("header", True) \
            .load("/Volumes/retail_catalog/bigmart_schema/bigmart_volume/BigMart Sales.csv")
df.display()
df.printSchema()

# %% [markdown]
# ## Select columns

# %%
# one way of select the columns
df_sel = df_sales.select("Item_Identifier","Item_Type","Item_Fat_Content")

# %%
df_sales.select(col("Item_Identifier"), col("Item_Type"), col("Item_Fat_Content")).display()

# %% [markdown]
# ## ALIAS

# %%
#df_sales.select(col("Item_Identifier").alias("Item_ID")).display()

df_sales.select(col("Item_Identifier").alias("Item_id"), col("Outlet_Establishment_Year").alias("Item_Esta_Year")).display()

# %% [markdown]
# ### FILTER/WHERE Transformations

# %% [markdown]
# ###1.filter data with fact content = Regular

# %%
df_sales.filter(col("Item_Fat_Content")== 'Regular').display()

# %% [markdown]
# ###2.Slice the data with item type = soft Drinks and weight < 10

# %%
# item type = soft Drinks
# weight < 10
df_sales.select(col("Item_Type"), col("Item_Weight")).display()

# %%
df_sales.select("Item_Type","Item_Fat_Content","Item_Identifier","Item_Weight").filter((col("Item_Type") == "Soft Drinks") & (col("Item_Weight") < 10)).display()

# %% [markdown]
# ###3.Fetch the data with Tier in (Tier1 or Tier 2) and outlet Size Null

# %%
# Outlet_Location_Type in Tier 1 or Tier 2
# Outlet_Size  = Null


df_sales.filter((col("Outlet_Location_Type").isin("Tier 1" , "Tier 2")) & (col("Outlet_Size").isNull())).display()

# %% [markdown]
# ## withColumnRenamed

# %%
df_sales.withColumnRenamed("Item_Weight","Item_wgt") \
        .withColumnRenamed("Item_Identifier","Item_ID").display()

# %% [markdown]
# ##withColumn
# ### 1. new colum
# ### 2. modify the existing column data

# %%
df_sales = df_sales.withColumn("Flag",lit("New"))

# %%
df_sales.display()

# %%
df_sales = df_sales.withColumn("multiply", col("Item_Weight")* col("Item_MRP"))

# %%
df_sales.display()

# %% [markdown]
# ###Change the content of the column
# ### regexp_replace

# %%
df_sales=  df_sales.withColumn("Item_Fat_Content", regexp_replace(col("Item_Fat_Content"),"Regular","Reg")) \
    .withColumn("Item_Fat_Content", regexp_replace(col("Item_Fat_Content"),"Low Fat", "LF"))

# %% [markdown]
# ## Type Casting

# %%
df_sales.printSchema()

# %%
df_sales = df_sales.withColumn("Item_weight", col("Item_Weight").cast(StringType()))

# %%
df_sales.printSchema()

# %% [markdown]
# # sort/orderBy

# %% [markdown]
# asc order or desc order

# %%
df_sales.sort(col("Item_weight").desc()).display()

# %%
df_sales.sort(col("Item_Visibility").asc()).display()

# %%
df_sales.sort(["Item_weight","Item_Visibility"], ascending = [0,1]).display()

# %% [markdown]
# ## Limit

# %%
df_sales.limit(10).display()

# %% [markdown]
# # DROP - COLUMNS

# %%
df_sales.drop(col("Flag")).display()

# %%
df_sales.drop("Item_Visibility","Item_Type").display()

# %% [markdown]
# ## Drop-Duplicates

# %% [markdown]
# ###remove the same columns
# ###to remove the duplicates in the specific column level

# %%
df_sales.dropDuplicates().display()

# %%
df_sales.distinct().display()

# %%
df_sales.dropDuplicates(subset = ["Item_Type"]).display()

# %% [markdown]
# ## UNION and UNION BYNAME

# %% [markdown]
# PREPARING DataFrames

# %%
# -------- DataFrame A --------
data_a = [
    (1, "Alice"),
    (2, "Bob")
]

schema_a = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True)
])

df_a = spark.createDataFrame(data_a, schema_a)

# -------- DataFrame B --------
data_b = [
    (3, "Charlie"),
    (4, "David")
]

schema_b = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True)
])

df_b = spark.createDataFrame(data_b, schema_b)

data_c = [
    ("Charlie", 3),
    ("David", 4)
]

schema_c = StructType([
    StructField("name", StringType(), True),
    StructField("id", IntegerType(), True)
])

df_c = spark.createDataFrame(data_c, schema_c)

# %%
df_a.display()
df_b.display()

# %%
df_a.union(df_b).display()

# %% [markdown]
# ##unionByName

# %%
df_a.unionByName(df_c).display()

# %% [markdown]
# # String Functions

# %% [markdown]
# ## INITCAP()
# ## UPPPER()
# ## LOWER()

# %%
df_sales.select("Item_Type").display()

# %% [markdown]
# initcap()

# %%
df_sales.select(initcap("Item_Type")).display()

# %%
df_sales.select(lower("Item_Type")).display()

# %%
df_sales.select(upper("Item_Type")).display()

# %%
from pyspark.sql.functions import initcap,lower,upper

df_sales.select(initcap("Item_Type").alias("upped_item_type")).display()

# %% [markdown]
# ##DATE FUNCTIONS
#     CURRENT_DATE()
#     DATE_ADD()
#     DATE_SUB()   :: INSTEAD WORKAROUND

# %%
df_sales = df_sales.withColumn("cur_date", current_date())

# %% [markdown]
# Date_add()
#
# week after  (7) days

# %%
df_sales=df_sales.withColumn("week_after",date_add("cur_date",7))

# %% [markdown]
# Date_sub()

# %%
df_sales=df_sales.withColumn("week_before", date_sub("cur_date",7))

# %%
df_sales = df_sales.withColumn("week_before", date_add("week_after",-7))

# %% [markdown]
# ##DATE_DIFF

# %%
df_sales = df_sales.withColumn("datediff", date_diff("week_after","cur_date"))

# %% [markdown]
# #DATE_FORMAT()

# %%
df_sales = df_sales.withColumn("week_before", date_format("week_before","dd-MM-yyyy"))

# %% [markdown]
# ##HANDLING NULLS
#
#   * dropping nulls
#   * filling nulls

# %% [markdown]
# ###Dropping nulls

# %%
df_sales.dropna('all').display()

# %%
df_sales.dropna("any").display()

# %%
df_sales.dropna(subset = ["Item_weight"]).display()

# %% [markdown]
# ## filling the null with names

# %%
df_sales.fillna("notavalable").display()

df_sales.fillna("Not available", subset = ["Outlet_Size"]).display()

# %% [markdown]
# ## SPLIT AND INDEXING

# %% [markdown]
# # Window concept
#   * ROW NUMBER()
#   * RANK()
#   * DENSE_RANK()

# %%
df_sales.display()

# %%
from pyspark.sql.window import Window


df_sales = df_sales.withColumn("rowCol", row_number().over(Window.orderBy('Item_Identifier')))

# %% [markdown]
# * RANK()
# * DENSE_RANK()

# %%
 df_sales.withColumn("rank", rank().over(Window.orderBy(col('Item_Identifier').desc()))) \
    .withColumn("Dense_Rank", dense_rank().over(Window.orderBy(col('Item_identifier').desc()))).display()

# %%
from pyspark.sql.functions import row_number, rank, dense_rank, col
from pyspark.sql.window import Window




df_sales.withColumn("rank_in_outlet", rank().over(Window.partitionBy('Outlet_Identifier') \
    .orderBy(col('Item_MRP').desc()))).display()

# %%
df_sales.withColumn("den_rank_in_outlet", dense_rank().over(Window.partitionBy("Item_Identifier") \
    .orderBy(col("Item_MRP").desc()))).display()

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import *

window_spec = Window.partitionBy("Item_Identifier").orderBy(col("Item_MRP").desc())

# %%
df_sales.withColumn("rank_wind", lag("Item_MRP", 1).over(window_spec)).display()

# %%
df_sales.withColumn("rank_wind", lead("Item_MRP", 1).over(window_spec)).display()

# %%
df_sales.withColumn("rank_wind", sum("Item_MRP").over(window_spec)).display()

# %%
running_window = window_spec.rowsBetween(Window.unboundedPreceding, Window.currentRow)

df_sales.withColumn("running_sum", sum("Item_MRP").over(running_window)).display()

# %%
moving_window = window_spec.rowsBetween(-1, 0)

# %%
df_sales.withColumn("Moving_avg", avg("Item_MRP").over(moving_window)).display()

# %%
df_sales.withColumn("Moving_avg", max("Item_MRP").over(moving_window)).display()

# %%
df_sales.withColumn("Moving_avg", min("Item_MRP").over(moving_window)).display()

# %% [markdown]
# # USER DEFINED FUNCTIONS (UDF'S)

# %% [markdown]
# STEP-1

# %%
def my_func(x):
  return x*x

# %% [markdown]
# STEP-2

# %%
my_udf = udf(my_func)

# %%
df_sales.withColumn('mynew_col', my_udf("Item_MRP")).display()

# %% [markdown]
# DATA WRITING

# %% [markdown]
# ##CSV

# %%
df_sales.write.format('csv') \
  .save('/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales.csv')

# %% [markdown]
# # append

# %%
df_sales.write.format('csv') \
    .mode("append") \
        .save('/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_append1.csv')
# or
df_sales.write.format('csv') \
    .mode("append") \
        .option('path', '/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_append2.csv') \
            .save()

# %% [markdown]
# # overwrite

# %%
df_sales.write.format('csv') \
    .mode("overwrite") \
        .option('path', '/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_overwrite.csv') \
            .save()

# %% [markdown]
# ERROR

# %%
df_sales.write.format('csv') \
    .mode('error') \
        .option('path', '/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_error.csv') \
            .save()

# %% [markdown]
# # IGNORE

# %%
df_sales.write.format('csv') \
    .mode('ignore') \
        .option('path', '/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_error.csv') \
            .save()

# %% [markdown]
# ##PARQUET FILE FORMAT

# %%
df_sales.write.format('parquet') \
    .mode('append') \
        .option('path', '/Volumes/retail_catalog/bigmart_schema/bigmart_volume/data_sales_error_parquet') \
            .save()

# %% [markdown]
# ## table

# %%
df_sales.write.format('delta') \
    .mode('overwrite') \
        .saveAsTable('my_table')

# %%
# %sql
select * from my_table

# %%
# %sql
select * from my_table
where Item_Identifier = 'FDG12'

# %%
df_sales.display()

# %% [markdown]
# #TEMP_VIEW()

# %% [markdown]
# SPARK SQL

# %% [markdown]
# ##CREATE TEMP VIEW()

# %%
df_sales.createTempView("sales")

# %%
df_sql = spark.sql("SELECT * FROM sales WHERE Item_Type = 'Soft Drinks'")

# %%
df_sql.display()
